# %% [markdown]
# ## 作業:
# 在課堂中，檢定 $𝐻_0:𝜇≤0，𝐻_1:𝜇>0 $，假設在 $𝐻_0$ 為真下，分配為 $N(0,1)$， $𝐻_1$ 為真下，分配為 $N(2,1)$。
# 假設 $\overline{𝑋}>1$，拒絕 $𝐻_0$。
# 如果拒絕域改變時，𝛼 和 𝛽 會怎樣變化?

# %% [markdown]
# ### Q1: 假設 $\overline{𝑋}>2$，拒絕 $𝐻_0$，𝛼 會變大/變小? 𝛽 會變大/變小?

# %% [markdown]
# Ans: 𝛼 會變小，𝛽 會變大

# %% [markdown]
# ### Q2: 假設 $\overline{𝑋}>0.2$，拒絕 $𝐻_0$，𝛼 會變大/變小? 𝛽 會變大/變小?

# %% [markdown]
# Ans: 𝛼 會變大，𝛽 會變小

# %% [markdown]
# ### Q3: 𝛼 和 𝛽  有關聯性?

# %% [markdown]
# Ans: 有關聯性，成負相關
